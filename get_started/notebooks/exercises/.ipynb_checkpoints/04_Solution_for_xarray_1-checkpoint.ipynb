# %% [markdown]
# <img align="right" src="../../../additional_data/banner_siegel.png" style="width:1000px;">

# %% [markdown]
# # Exercise I for using xarray library
#
# * [**Sign up to the JupyterHub**](https://www.phenocube.org/) to run this notebook interactively from your browser
# * **Compatibility:** Notebook currently compatible with the Open Data Cube environments of the University of Wuerzburg

# %% [markdown]
# ## Load packages
#
# Import following libraries; datacube and with_ui_cbk from odc.ui.

# %%
import datacube
from odc.ui import with_ui_cbk

# %% [markdown]
# ## Connect to eo2cube Datacube
#
# Connect to eo2cube Datacube and use app argument to define a name of this exercise.

# %%
dc = datacube.Datacube(app = "Exercise_for_xarrays")

# %% [markdown]
# ## Load data with the dc.load() function
#
# Load Sentinel-2 data from the eo2cube datacube with dc.load() function and following options.<br>
#
# * Longitude range: (24.80, 24.95), <br>
# * Latitude range: (-28.88, -28.79) <br>
# * Time range: 2020-06-01 to 2020-08-31 <br>
# * Bands: blue, green, red <br>
# * Output coordinate system: EPSG:32734 <br>
# * Resolution: 10m <br>
# * Select only solar days
# * Use loading bar

# %%
data = dc.load(product= "s2_l2a",
               x = (24.80, 24.95),
               y = (-28.88, -28.79),
               output_crs = "EPSG:32734",
               time = ("2020-06-01", "2020-08-31"),
               measurements = ["blue", "green", "red"],
               resolution = (-10,10),
               group_by = "solar_day",
               progress_cbk=with_ui_cbk())

data
# Out:
# VBox(children=(HBox(children=(Label(value=''), Label(value='')), layout=Layout(justify_content='space-between'…
# /opt/conda/lib/python3.9/site-packages/datacube/drivers/postgres/_api.py:564: SAWarning: Class CommonTimestamp will not make use of SQL compilation caching as it does not set the 'inherit_cache' attribute to ``True``.  This can have significant performance implications including some performance degradations in comparison to prior SQLAlchemy versions.  Set this attribute to True if this object can make use of the cache key generated by the superclass.  Alternatively, this attribute may be set to False which will disable this warning. (Background on this error at: https://sqlalche.me/e/14/cprf)
#   return self._connection.execute(select_query)
# /opt/conda/lib/python3.9/site-packages/datacube/drivers/postgres/_api.py:564: SAWarning: Class Float8Range will not make use of SQL compilation caching as it does not set the 'inherit_cache' attribute to ``True``.  This can have significant performance implications including some performance degradations in comparison to prior SQLAlchemy versions.  Set this attribute to True if this object can make use of the cache key generated by the superclass.  Alternatively, this attribute may be set to False which will disable this warning. (Background on this error at: https://sqlalche.me/e/14/cprf)
#   return self._connection.execute(select_query)
# <xarray.Dataset>
# Dimensions:      (time: 18, y: 1047, x: 1498)
# Coordinates:
#   * time         (time) datetime64[ns] 2020-06-03T08:28:16 ... 2020-08-27T08:...
#   * y            (y) float64 6.809e+06 6.809e+06 ... 6.799e+06 6.799e+06
#   * x            (x) float64 8.707e+05 8.707e+05 ... 8.857e+05 8.857e+05
#     spatial_ref  int32 32734
# Data variables:
#     blue         (time, y, x) uint16 619 636 640 634 648 ... 1094 1056 1048 1096
#     green        (time, y, x) uint16 887 896 884 889 907 ... 1632 1620 1672 1714
#     red          (time, y, x) uint16 1218 1268 1278 1258 ... 2364 2354 2378 2422
# Attributes:
#     crs:           EPSG:32734
#     grid_mapping:  spatial_ref

# %% [markdown]
# ## Explore the structure of dataset
#
# 1. Check the coordinates of the dataset.

# %%
data.coords
# Out:
# Coordinates:
#   * time         (time) datetime64[ns] 2020-06-03T08:28:16 ... 2020-08-27T08:...
#   * y            (y) float64 6.809e+06 6.809e+06 ... 6.799e+06 6.799e+06
#   * x            (x) float64 8.707e+05 8.707e+05 ... 8.857e+05 8.857e+05
#     spatial_ref  int32 32734

# %% [markdown]
# 2. Check all the time stamps of the dataset

# %%
data.time
# Out:
# <xarray.DataArray 'time' (time: 18)>
# array(['2020-06-03T08:28:16.000000000', '2020-06-08T08:28:20.000000000',
#        '2020-06-13T08:28:16.000000000', '2020-06-18T08:28:20.000000000',
#        '2020-06-23T08:28:17.000000000', '2020-06-28T08:28:19.000000000',
#        '2020-07-03T08:28:16.000000000', '2020-07-08T08:28:18.000000000',
#        '2020-07-13T08:28:16.000000000', '2020-07-18T08:28:19.000000000',
#        '2020-07-23T08:28:16.000000000', '2020-07-28T08:28:20.000000000',
#        '2020-08-02T08:28:17.000000000', '2020-08-07T08:28:20.000000000',
#        '2020-08-12T08:28:17.000000000', '2020-08-17T08:28:20.000000000',
#        '2020-08-22T08:28:18.000000000', '2020-08-27T08:28:19.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time         (time) datetime64[ns] 2020-06-03T08:28:16 ... 2020-08-27T08:...
#     spatial_ref  int32 32734
# Attributes:
#     units:    seconds since 1970-01-01 00:00:00

# %% [markdown]
# 3. Print only red band values

# %%
data.red.values
# Out:
# array([[[1218, 1268, 1278, ..., 1144, 1064, 1246],
#         [1218, 1188, 1236, ..., 1176, 1078, 1078],
#         [1182, 1132, 1196, ..., 1270, 1222, 1196],
#         ...,
#         [1476, 1508, 1606, ..., 2046, 2054, 1936],
#         [1536, 1454, 1604, ..., 2056, 2090, 2056],
#         [1544, 1520, 1656, ..., 2156, 2138, 2096]],
#
#        [[1300, 1346, 1348, ..., 1264, 1144, 1310],
#         [1284, 1320, 1290, ..., 1294, 1202, 1238],
#         [1290, 1288, 1262, ..., 1342, 1306, 1278],
#         ...,
#         [1624, 1602, 1680, ..., 2128, 2112, 2046],
#         [1666, 1556, 1726, ..., 2104, 2158, 2200],
#         [1710, 1656, 1756, ..., 2220, 2200, 2252]],
#
#        [[1256, 1252, 1316, ..., 1140, 1126, 1246],
#         [1242, 1186, 1262, ..., 1256, 1186, 1168],
#         [1198, 1148, 1246, ..., 1326, 1208, 1236],
#         ...,
#         [1600, 1588, 1698, ..., 2110, 2052, 2014],
#         [1660, 1516, 1674, ..., 2100, 2144, 2142],
#         [1708, 1654, 1712, ..., 2172, 2152, 2190]],
#
#        ...,
#
#        [[1948, 1924, 1964, ..., 1428, 1554, 1578],
#         [1930, 1950, 1982, ..., 1504, 1550, 1450],
#         [1902, 1938, 1946, ..., 1626, 1560, 1438],
#         ...,
#         [2160, 2258, 2276, ..., 2454, 2430, 2362],
#         [2192, 2226, 2288, ..., 2428, 2468, 2472],
#         [2216, 2200, 2334, ..., 2476, 2522, 2570]],
#
#        [[1866, 1854, 1870, ..., 1532, 1552, 1614],
#         [1836, 1878, 1914, ..., 1548, 1522, 1480],
#         [1832, 1878, 1928, ..., 1600, 1576, 1504],
#         ...,
#         [2170, 2260, 2260, ..., 2388, 2364, 2374],
#         [2182, 2188, 2300, ..., 2404, 2432, 2424],
#         [2210, 2232, 2292, ..., 2370, 2454, 2482]],
#
#        [[1924, 1914, 1936, ..., 1560, 1504, 1644],
#         [1914, 1896, 1906, ..., 1544, 1516, 1530],
#         [1914, 1902, 1950, ..., 1560, 1568, 1506],
#         ...,
#         [2152, 2164, 2292, ..., 2334, 2350, 2312],
#         [2172, 2160, 2242, ..., 2328, 2364, 2378],
#         [2194, 2204, 2260, ..., 2354, 2378, 2422]]], dtype=uint16)

# %% [markdown]
# 4. Select green band data at the third time stamp

# %%
data.green[2]
# Out:
# <xarray.DataArray 'green' (y: 1047, x: 1498)>
# array([[ 859,  871,  888, ...,  794,  720,  854],
#        [ 802,  838,  850, ...,  842,  778,  826],
#        [ 820,  810,  857, ...,  821,  832,  824],
#        ...,
#        [1144, 1114, 1210, ..., 1500, 1476, 1430],
#        [1144, 1058, 1200, ..., 1458, 1506, 1530],
#        [1188, 1152, 1240, ..., 1544, 1516, 1566]], dtype=uint16)
# Coordinates:
#     time         datetime64[ns] 2020-06-13T08:28:16
#   * y            (y) float64 6.809e+06 6.809e+06 ... 6.799e+06 6.799e+06
#   * x            (x) float64 8.707e+05 8.707e+05 ... 8.857e+05 8.857e+05
#     spatial_ref  int32 32734
# Attributes:
#     units:         1
#     nodata:        0
#     crs:           EPSG:32734
#     grid_mapping:  spatial_ref

# %% [markdown]
# 5. Select data of all spectral bands at the last time stamp

# %%
data.isel(time=[-1])
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 1, y: 1047, x: 1498)
# Coordinates:
#   * time         (time) datetime64[ns] 2020-08-27T08:28:19
#   * y            (y) float64 6.809e+06 6.809e+06 ... 6.799e+06 6.799e+06
#   * x            (x) float64 8.707e+05 8.707e+05 ... 8.857e+05 8.857e+05
#     spatial_ref  int32 32734
# Data variables:
#     blue         (time, y, x) uint16 954 927 969 979 946 ... 1094 1056 1048 1096
#     green        (time, y, x) uint16 1398 1376 1396 1388 ... 1632 1620 1672 1714
#     red          (time, y, x) uint16 1924 1914 1936 1976 ... 2364 2354 2378 2422
# Attributes:
#     crs:           EPSG:32734
#     grid_mapping:  spatial_ref

# %% [markdown]
# 6. Select data of all spectral bands for the year 2020 August.

# %%
data.sel(time='2020-08')
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 6, y: 1047, x: 1498)
# Coordinates:
#   * time         (time) datetime64[ns] 2020-08-02T08:28:17 ... 2020-08-27T08:...
#   * y            (y) float64 6.809e+06 6.809e+06 ... 6.799e+06 6.799e+06
#   * x            (x) float64 8.707e+05 8.707e+05 ... 8.857e+05 8.857e+05
#     spatial_ref  int32 32734
# Data variables:
#     blue         (time, y, x) uint16 936 907 898 899 930 ... 1094 1056 1048 1096
#     green        (time, y, x) uint16 1280 1246 1262 1278 ... 1632 1620 1672 1714
#     red          (time, y, x) uint16 1808 1804 1804 1804 ... 2364 2354 2378 2422
# Attributes:
#     crs:           EPSG:32734
#     grid_mapping:  spatial_ref

# %% [markdown]
# ## Reshape the dataset
#
# First, subset the dataset of all spectral bands for the day "2020-08-02" and convert it to 4-dimension DataArray by adding the band to the dimension.
#
# Next, convert the 4-dimension DataArray back to a 3-dimension Dataset by setting the "time" as DataVariable.
#
# Check the dimensions using attributes.

# %%
da = data.sel(time='2020-08-02').to_array().rename({"variable":"band"})
da.dims
# Out:
# ('band', 'time', 'y', 'x')

# %%
ds_reshp = da.to_dataset(dim="time")
ds_reshp.dims
# Out:
# Frozen({'band': 3, 'y': 1047, 'x': 1498})

# %% [markdown]
# ***
#
# ## Additional information
#
# <font size="2">This notebook for the usage in the Open Data Cube entities of the [Department of Remote Sensing](http://remote-sensing.org/), [University of Wuerzburg](https://www.uni-wuerzburg.de/startseite/), is adapted from [Geoscience Australia](https://github.com/GeoscienceAustralia/dea-notebooks), published using the Apache License, Version 2.0. Thanks! </font>
#
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Australia data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
#
# **Contact:** If you would like to report an issue with this notebook, you can file one on [Github](https://github.com).
#
# **Last modified:** June 2022
